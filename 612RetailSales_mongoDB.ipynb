# %% [markdown]
# <a href="https://colab.research.google.com/github/wendydonzse/GDDA612_project1/blob/main/612RetailSales_mongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/ColabNotebooks/612') # Use os.chdir to change directory in Python

# %%
ls
# Out:
#  20240817-053050/                    'MongoDB connection.ipynb'
#  20240817-060030/                     retail_full.csv
#  612_Testing.ipynb                    retail_full_local.csv
#  clean_vgsales.csv                    retail_sales_clean.csv
#  GDD612_A2Project2_850001206_1.docx   retailsales_clothing1000.csv
#  GDD612_A2Project2_850001206_2.docx   retail_sales_dataset.csv
#  GDD612_A2Project2_850001206.docx     tidy_vgsales.csv
#  GDDA612_BACKUP_20240817045725/      'Untitled0 (1).ipynb'
#  GDDA612_BACKUP_20240817051306/       vgsales_clean.csv
#  GDDA612_BACKUP_20240817051445/       vgsales.csv
# 'Google drive and colab (1).ipynb'

# %%
# Step1 install pymonogo
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 13.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv('retail_sales_clean.csv')

# %%
df.head()
# Out:
#    Transaction ID Customer ID  Beauty  Clothing  Electronics
# 0               1     CUST001   150.0       0.0          0.0
# 1               2     CUST002     0.0    1000.0          0.0
# 2               3     CUST003     0.0       0.0         30.0
# 3               4     CUST004     0.0     500.0          0.0
# 4               5     CUST005   100.0       0.0          0.0

# %%
# Step2 Import MongoClient
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

# %%
# Step 3: Connect to MongoDB
url = "mongodb+srv://wendydo2021:7duGfndmtS3knRhX@cluster0.5yrvlto.mongodb.net/"


client = MongoClient("mongodb+srv://wendydo2021:7duGfndmtS3knRhX@cluster0.5yrvlto.mongodb.net/")

try:
    # Create MongoClien objective
    db = client['Retail_Sales']
    # Convert DataFrame to a list of dictionaries
    data_dict = df.to_dict(orient='records')
    # Insert data into a collection named 'Retail_Sales'
    collection = db['Retail_Sales']
    collection.insert_many(data_dict)
    # Trying to connect to the server
    client.admin.command('ping')
    # Access collection
    collection = db['MongoDB_V1']
    print("successful connection")
except ConnectionFailure:
    print("connection fail")
# Out:
# successful connection

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['ac-zdf8lxp-shard-00-01.5yrvlto.mongodb.net:27017', 'ac-zdf8lxp-shard-00-02.5yrvlto.mongodb.net:27017', 'ac-zdf8lxp-shard-00-00.5yrvlto.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-nqg86d-shard-0', tls=True), 'Retail_Sales'), 'MongoDB_V1')

# %%
# Step 4: Inser Data
# You can insert data into the collection using insert_one() for a single document or insert_many() for multiple documents.
# Insert a Single Document
# Single document
document = {"Transaction ID": "1001", "Customer ID": "CUST01001", "Beauty": "50", "Clothing" : "500", "Electronics" : "0"}
result = collection.insert_one(document)
print("Inserted document id:", result.inserted_id)
print(result)
# Out:
# Inserted document id: 66c06e6f3c58146530ed9474
# InsertOneResult(ObjectId('66c06e6f3c58146530ed9474'), acknowledged=True)

# %%
# Retrieve documents from the 'retail_sales' collection
collection = db['Retail_Sales']
documents = collection.find()
# Display the documents
for doc in documents:
    print(doc)
# Out:
# {'_id': ObjectId('66c003f59bd23bbce2d807e3'), 'Transaction ID': 1, 'Customer ID': 'CUST001', 'Beauty': 150.0, 'Clothing': 0.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e4'), 'Transaction ID': 2, 'Customer ID': 'CUST002', 'Beauty': 0.0, 'Clothing': 1000.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e5'), 'Transaction ID': 3, 'Customer ID': 'CUST003', 'Beauty': 0.0, 'Clothing': 0.0, 'Electronics': 30.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e6'), 'Transaction ID': 4, 'Customer ID': 'CUST004', 'Beauty': 0.0, 'Clothing': 500.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e7'), 'Transaction ID': 5, 'Customer ID': 'CUST005', 'Beauty': 100.0, 'Clothing': 0.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e8'), 'Transaction ID': 6, 'Customer ID': 'CUST006', 'Beauty': 30.0, 'Clothing': 0.0, 'Electronics': 0.0}
# ...

# %%
import pandas as pd
df1 = pd.read_csv('retail_full.csv')

# %%
df1.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3            50.0         150.0
# 1         2           500.0        1000.0
# 2         1            30.0          30.0
# 3         1           500.0         500.0
# 4         2            50.0         100.0

# %%
try:
    # Create MongoClien objective
    db1 = client['Retail_full']
    # Convert DataFrame to a list of dictionaries
    data_dict1 = df1.to_dict(orient='records')
    # Insert data into a collection named 'Retail_Sales'
    collection1 = db['Retail_full']
    collection1.insert_many(data_dict1)
    # Trying to connect to the server
    client.admin.command('ping')
    # Access collection
    collection1 = db['Retail_full']
    print("successful connection")
except ConnectionFailure:
    print("connection fail")
# Out:
# successful connection

# %%
collection1
# Out:
# Collection(Database(MongoClient(host=['ac-zdf8lxp-shard-00-01.5yrvlto.mongodb.net:27017', 'ac-zdf8lxp-shard-00-02.5yrvlto.mongodb.net:27017', 'ac-zdf8lxp-shard-00-00.5yrvlto.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-nqg86d-shard-0', tls=True), 'Retail_Sales'), 'Retail_full')

# %%
# Retrieve documents from the 'retail_full' collection
documents1 = collection1.find()
# Display the documents
for doc in documents1:
    print(doc)
# Out:
# {'_id': ObjectId('66c003f59bd23bbce2d807e3'), 'Transaction ID': 1, 'Customer ID': 'CUST001', 'Beauty': 150.0, 'Clothing': 0.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e4'), 'Transaction ID': 2, 'Customer ID': 'CUST002', 'Beauty': 0.0, 'Clothing': 1000.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e5'), 'Transaction ID': 3, 'Customer ID': 'CUST003', 'Beauty': 0.0, 'Clothing': 0.0, 'Electronics': 30.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e6'), 'Transaction ID': 4, 'Customer ID': 'CUST004', 'Beauty': 0.0, 'Clothing': 500.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e7'), 'Transaction ID': 5, 'Customer ID': 'CUST005', 'Beauty': 100.0, 'Clothing': 0.0, 'Electronics': 0.0}
# {'_id': ObjectId('66c003f59bd23bbce2d807e8'), 'Transaction ID': 6, 'Customer ID': 'CUST006', 'Beauty': 30.0, 'Clothing': 0.0, 'Electronics': 0.0}
# ...

# %%
# Sorted by Total Amount to find out who is the top dollars spending in the 'Retail_full' collection
TopDollars = collection1.find().sort('Total Amount', -1)  # -1 for descending order
# Display the sorted documents
for doc in TopDollars:
    print(doc)
# Out:
# {'_id': ObjectId('66c017669bd23bbce2d80bdb'), 'Transaction ID': 15, 'Date': '2023-01-16', 'Customer ID': 'CUST015', 'Gender': 'Female', 'Age': 42, 'Product Category': 'Electronics', 'Quantity': 4, 'Price per Unit': 500.0, 'Total Amount': 2000.0}
# {'_id': ObjectId('66c017669bd23bbce2d80c0d'), 'Transaction ID': 65, 'Date': '2023-12-05', 'Customer ID': 'CUST065', 'Gender': 'Male', 'Age': 51, 'Product Category': 'Electronics', 'Quantity': 4, 'Price per Unit': 500.0, 'Total Amount': 2000.0}
# {'_id': ObjectId('66c017669bd23bbce2d80c14'), 'Transaction ID': 72, 'Date': '2023-05-23', 'Customer ID': 'CUST072', 'Gender': 'Female', 'Age': 20, 'Product Category': 'Electronics', 'Quantity': 4, 'Price per Unit': 500.0, 'Total Amount': 2000.0}
# {'_id': ObjectId('66c017669bd23bbce2d80c16'), 'Transaction ID': 74, 'Date': '2023-11-22', 'Customer ID': 'CUST074', 'Gender': 'Female', 'Age': 18, 'Product Category': 'Beauty', 'Quantity': 4, 'Price per Unit': 50, 'Total Amount': 2000.0}
# ...

# %%
# Count the number of documents in the 'retail_sales' collection
count1 = collection1.count_documents({})
count = collection.count_documents({})
# Display the count
print(f"Number of documents on Retail_clean is: {count}")
print(f"Number of documents on Retail_full is: {count1}")
# Out:
# Number of documents on Retail_clean is: 2001
# Number of documents on Retail_full is: 4000

# %%
# Define the aggregation pipeline
pipeline = [
       {"$group": {"_id": "$Product Category", "TotalSales": {"$sum": "$Total Amount"}}}
   ]

# Perform the aggregation
collection1 = db['Retail_full']
Category_DollarSpend = collection1.aggregate(pipeline)

# Display the Total amount for each Category:
for doc in Category_DollarSpend:
    print(doc)
# Out:
# {'_id': 'Clothing', 'TotalSales': 466740.0}
# {'_id': 'Electronics', 'TotalSales': 470715.0}
# {'_id': 'Beauty', 'TotalSales': 430545.0}
# {'_id': None, 'TotalSales': 0}

# %%
# Define the update criteria and the update operation
update_criteria = {"Product Category": "Beauty"}
update_operation = {"$set": {"Price per Unit": 50}}
# Perform the update
collection1.update_many(update_criteria, update_operation)
# Out:
# UpdateResult({'n': 921, 'electionId': ObjectId('7fffffff00000000000000ee'), 'opTime': {'ts': Timestamp(1723887281, 189), 't': 238}, 'nModified': 307, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1723887281, 189), 'signature': {'hash': b'0\xac\xf2\x84\xa1r\xe6\xa9\xf3[\x88Y\xe7\x93h\xc89\n\x046', 'keyId': 7366714338297511949}}, 'operationTime': Timestamp(1723887281, 189), 'updatedExisting': True}, acknowledged=True)

# %%
# Export the DataFrame to a JSON file
df1.to_json('retail_sales_clean_export.json', orient='records', lines=True)

# %%
df1.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3            50.0         150.0
# 1         2           500.0        1000.0
# 2         1            30.0          30.0
# 3         1           500.0         500.0
# 4         2            50.0         100.0

# %%
df.to_json('retail_sales_clean_export.json', orient='records', lines=True)

# %%
df.head()
# Out:
#    Transaction ID Customer ID  Beauty  Clothing  Electronics
# 0               1     CUST001     150         0            0
# 1               2     CUST002       0      1000            0
# 2               3     CUST003       0         0           30
# 3               4     CUST004       0       500            0
# 4               5     CUST005     100         0            0
